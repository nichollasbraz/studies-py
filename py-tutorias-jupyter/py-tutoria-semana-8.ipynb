# %% [markdown]
# # Live Class - Semana 6: 16/06/2026

# %% [markdown]
# ## Parte 1: Exercícios diversos

# %% [markdown]
# ## Exercício 1
# ### Item a
# Criar a função `dados()` que retorna um dicionário com os possíveis valores da soma das faces de dois dados e as probabilidades teóricas de cada valor.
# ### Item b
# Criar a função `soma_dados()` que simula o lançamento de dois dados e soma as duas faces. A função recebe como parâmetro de entrada a quantidade de repetições que a simulação deverá executar e conta a quantidade de vezes que cada resultado ocorre, retornando como resultado a frequênncia relativa observada de cada resultado e o valor da probabilidade teórica correspondente.

# %% [markdown]
# ## Exercício 2
# Use um loop para construir os conjuntos `mult3`, `mult5` e `mult7` de múltiplos não negativos de 3, 5, e 7, respectivamente, menores que 110. Então, usando estes três conjuntos, escreva expressões que retornem:
#
# * (a) Múltiplos de 35
# * (b) Múltiplos de 105
# * (c) Múltiplos de 3 ou 7
# * (d) Múltiplos de 3 ou 7, mas não ambos
# * (e) Múltiplos de 7 que não sejam múltiplos de 3

# %%
# print('(a) Múltiplos de 35\n...',)
# print('(b) Múltiplos de 105\n...',)
# print('(c) Múltiplos de 3 ou 7\n...',)
# print('(d) Múltiplos de 3ou 7, mas não de ambos\n...',)
# print('(e) Múltiplos de 7 que não são múltiplos de 3\n...',)

# %% [markdown]
# ## Exercício 3
# Implemente uma função chamada `nomes()` que não recebe nenhuma entrada e peça repetidamente ao usuário que digite o nome de um(a) aluno(a) em um curso. Quando o usuário digita a string vazia, a função deve imprimir para cada nome que foi informado, o número de alunos com esse nome.

# %% [markdown]
# ## Exercício 4
# Implemente uma função chamada `easyCrypto()` que recebe como entrada uma string e retorna uma string que é a versão encriptada da sua entrada de acordo com as seguintes regras:
# * Cada caractere em uma posição ímpar `i` no alfabeto será criptografado com o caractere na posição `i + 1`
# * Cada caractere em uma posição par `i` será encriptado com o caractere na posição `i - 1`
#
# Os caracteres em minúsculas devem permanecer em minúsculas e os caracteres em maiúsculas devem permanecer em maiúsculas.

# %% [markdown]
# ## Parte 2: Learning checks - unidade 5

# %% [markdown]
# ## Learning check 1
# Escreva uma função chamada `removerDuplicatas()` que toma como entrada uma lista de palavras (isto é, strings) e retorna uma lista ordenada lexicograficamente com todas as palavras repetidas removidas. Por exemplo:
# ```
# >>> words = ['hello', 'mother', 'hello', 'father', 'here', 'i', 'am', 'hello']
# >>> removerDuplicatas(words)
# ['am', 'father', 'hello', 'here', 'i', 'mother']
# ```

# %% [markdown]
# ## Learning check 2
# Escreva uma função chamada `alunosAprovados()` que recebe como entrada um dicionário que contém as notas dos alunos de uma disciplina do curso de Python. As chaves são nomes de alunos, e os valores são notas (números inteiros) que eles tiraram na disciplina. A sua função deve retornar uma lista, ordenada lexicograficamente, contendo o nome dos alunos que tiraram nota maior ou igual a 9. Por exemplo:
#
# ```
# >>> notas = {'Fulano de Tal':3, 'Sicrano Semiour': 9, 'Jenn Doe':1}
# >>> alunosAprovados(notas)
# ['Sicrano Semiour']
# >>> notas = {'Zinca Zenu':10,'Fulano de Tal':3, 'Sicrano Semiour': 9, 'Jenn Doe':1}
# >>> alunosAprovados(notas)
# ['Sicrano Semiour','Zinca Zenu']
# ```

# %% [markdown]
# ## Learning check 3
# Duas palavras são anagramas se as letras de uma podem ser reordenadas para formar a outra. Por exemplo, **pato**, **topa** e **opta** são todos anagramas um do outro. Uma maneira de identificar rapidamente se duas palavras arbitrárias são anagramas é ordenar as letras em cada palavra para produzir uma assinatura. Por exemplo, as palavras acima têm todas a assinatura **aopt**. Duas palavras são anagramas se e somente se elas tiverem a mesma assinatura.
#
# Escreva uma função chamada `anagramas()` que toma como entrada uma lista de palavras (strings) todas com letras minúsculas. A função retorna um dicionário no qual as chaves são assinaturas de palavras na lista de entrada e o valor para cada chave é o conjunto (set) de todas as palavras no arquivo que tem essa assinatura em particular.

# %% [markdown]
# ## Learning check 4
# **Parte 1**
#
# Escreva uma função chamada `moeda()` que retorna 'Cara' ou 'Coroa' com a mesma probabilidade.
#
# **Parte 2**
#
# Implemente uma função chamada `caras()` que não recebe nenhuma entrada e simula um jogo que consiste em lançar a moeda e contar quantas vezes se obtém cara antes de a primeira coroa aparecer. Quando a primeira coroa aparecer, a função deve retornar o número caras obtidas até aquele ponto. Por exemplo, se a simulação resultar em 'Cara', 'Cara', 'Cara', 'Coroa', a função deve retornar 3.

# %% [markdown]
# ## Learning check 5
# Escreva uma função `diceprob()` que toma como entrada um número r, que representa o resultado da soma do lance de um par de dados (ou seja, um inteiro entre 2 e 12) e simula lances repetidos de um par de dados (não viciados) até que se obtenha por 100 vezes a soma dos dois dados igual ao valor r. A sua função deve imprimir quantos lances foram necessários para obter 100 lances com soma r.

# %% [markdown]
# ## Learning check 6
# Escreva uma função `histograma()` que recebe como entrada uma string e retorna um dicionário que conta o número de ocorrências de cada caractere na string dada.

# %% [markdown]
# ## Learning check 7
# Implemente uma função chamada `indiceReverso()` que recebe como entrada um dicionário e constroi o mapeamento reverso que mapeia cada valor do dicionário de entrada na lista das chaves que estão associadas a ele.
